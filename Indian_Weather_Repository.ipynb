# %% [markdown]
# <a href="https://colab.research.google.com/github/anjithababuraj/CognoRise-Infotech/blob/main/Indian_Weather_Repository.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INDIAN WEATHER REPOSITORY(DAILY UPDATING)**

# %% [markdown]
# Create machine learning model for analyzing India's present weather trends and exploring the relationships between various weather parameters

# %% [markdown]
# The Indian Weather Repository dataset contains detailed weather information from different parts of India, including data on temperature, rainfall, wind speed, humidity, air quality, and sunrise/sunset times. This dataset is useful for machine learning projects like predicting the weather, studting climate change, checking air quality, and planning for farming or natural disasters. Using this data, we can create modles to understand weather patterns and make better decisions to handle environmental issues.

# %% [markdown]
# IMPORT REQUIRED LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# DATA LOADING

# %%
data=pd.read_csv('/content/IndianWeatherRepository.csv')
data
# Out:
#        country location_name          region  latitude  longitude  \
# 0        India    Ashoknagar  Madhya Pradesh     24.57      77.72
# 1        India        Raisen  Madhya Pradesh     23.33      77.80
# 2        India    Chhindwara  Madhya Pradesh     22.07      78.93
# 3        India         Betul  Madhya Pradesh     21.86      77.93
# 4        India   Hoshangabad  Madhya Pradesh     22.75      77.72
# ...        ...           ...             ...       ...        ...
# 101336   India        Niwari   Uttar Pradesh     28.88      77.53
# 101337   India       Saitual         Mizoram     23.97      92.58
# 101338   India       Ranipet      Tamil Nadu     12.93      79.33
# 101339   India       Tenkasi      Tamil Nadu      8.97      77.30
# 101340   India        Pendra     Maharashtra     21.93      74.15
#
#             timezone  last_updated_epoch      last_updated  \
# 0       Asia/Kolkata          1693286100  2023-08-29 10:45
# 1       Asia/Kolkata          1693286100  2023-08-29 10:45
# 2       Asia/Kolkata          1693286100  2023-08-29 10:45
# 3       Asia/Kolkata          1693286100  2023-08-29 10:45
# 4       Asia/Kolkata          1693286100  2023-08-29 10:45
# ...              ...                 ...               ...
# 101336  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101337  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101338  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101339  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101340  Asia/Kolkata          1709571600  2024-03-04 22:30
#
#         temperature_celsius  temperature_fahrenheit  ... air_quality_PM2.5  \
# 0                      27.5                    81.5  ...              12.6
# 1                      27.5                    81.5  ...              10.7
# 2                      26.3                    79.3  ...              16.8
# 3                      25.6                    78.1  ...               4.9
# 4                      27.2                    81.0  ...              11.4
# ...                     ...                     ...  ...               ...
# 101336                 17.0                    62.6  ...              59.9
# 101337                 14.3                    57.8  ...              93.5
# 101338                 22.6                    72.7  ...              58.7
# 101339                 29.0                    84.2  ...              35.3
# 101340                 19.4                    66.9  ...              16.1
#
#         air_quality_PM10  air_quality_us-epa-index  \
# 0                   18.5                         1
# 1                   14.2                         1
# 2                   20.7                         2
# 3                    6.6                         1
# 4                   14.8                         1
# ...                  ...                       ...
# 101336             111.3                         3
# 101337             102.3                         4
# 101338              71.4                         3
# 101339              45.1                         2
# 101340              26.0                         2
#
#         air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 0                                2  05:59 AM  06:41 PM  05:42 PM  03:38 AM
# 1                                1  06:00 AM  06:40 PM  05:39 PM  03:41 AM
# 2                                2  05:56 AM  06:34 PM  05:32 PM  03:39 AM
# 3                                1  06:00 AM  06:38 PM  05:36 PM  03:43 AM
# 4                                1  06:01 AM  06:39 PM  05:38 PM  03:42 AM
# ...                            ...       ...       ...       ...       ...
# 101336                           8  06:42 AM  06:21 PM  01:36 AM  11:43 AM
# 101337                          10  05:39 AM  05:24 PM  12:19 AM  10:55 AM
# 101338                           7  06:27 AM  06:22 PM  12:47 AM  12:17 PM
# 101339                           3  06:33 AM  06:32 PM  12:47 AM  12:35 PM
# 101340                           2  06:21 AM  06:07 PM  01:00 AM  11:42 AM
#
#              moon_phase  moon_illumination
# 0        Waxing Gibbous                 93
# 1        Waxing Gibbous                 93
# 2        Waxing Gibbous                 93
# 3        Waxing Gibbous                 93
# 4        Waxing Gibbous                 93
# ...                 ...                ...
# 101336  Waning Crescent                 46
# 101337  Waning Crescent                 46
# 101338  Waning Crescent                 46
# 101339  Waning Crescent                 46
# 101340  Waning Crescent                 46
#
# [101341 rows x 42 columns]

# %% [markdown]
# DATA INFORMATIONS

# %%
# first 5 rows of the data
data.head()
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693286100  2023-08-29 10:45                 27.5
# 1          1693286100  2023-08-29 10:45                 27.5
# 2          1693286100  2023-08-29 10:45                 26.3
# 3          1693286100  2023-08-29 10:45                 25.6
# 4          1693286100  2023-08-29 10:45                 27.2
#
#    temperature_fahrenheit  ... air_quality_PM2.5  air_quality_PM10  \
# 0                    81.5  ...              12.6              18.5
# 1                    81.5  ...              10.7              14.2
# 2                    79.3  ...              16.8              20.7
# 3                    78.1  ...               4.9               6.6
# 4                    81.0  ...              11.4              14.8
#
#    air_quality_us-epa-index  air_quality_gb-defra-index   sunrise    sunset  \
# 0                         1                           2  05:59 AM  06:41 PM
# 1                         1                           1  06:00 AM  06:40 PM
# 2                         2                           2  05:56 AM  06:34 PM
# 3                         1                           1  06:00 AM  06:38 PM
# 4                         1                           1  06:01 AM  06:39 PM
#
#    moonrise   moonset      moon_phase  moon_illumination
# 0  05:42 PM  03:38 AM  Waxing Gibbous                 93
# 1  05:39 PM  03:41 AM  Waxing Gibbous                 93
# 2  05:32 PM  03:39 AM  Waxing Gibbous                 93
# 3  05:36 PM  03:43 AM  Waxing Gibbous                 93
# 4  05:38 PM  03:42 AM  Waxing Gibbous                 93
#
# [5 rows x 42 columns]

# %%
# last 5 rows of the data
data.tail()
# Out:
#        country location_name         region  latitude  longitude  \
# 101336   India        Niwari  Uttar Pradesh     28.88      77.53
# 101337   India       Saitual        Mizoram     23.97      92.58
# 101338   India       Ranipet     Tamil Nadu     12.93      79.33
# 101339   India       Tenkasi     Tamil Nadu      8.97      77.30
# 101340   India        Pendra    Maharashtra     21.93      74.15
#
#             timezone  last_updated_epoch      last_updated  \
# 101336  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101337  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101338  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101339  Asia/Kolkata          1709571600  2024-03-04 22:30
# 101340  Asia/Kolkata          1709571600  2024-03-04 22:30
#
#         temperature_celsius  temperature_fahrenheit  ... air_quality_PM2.5  \
# 101336                 17.0                    62.6  ...              59.9
# 101337                 14.3                    57.8  ...              93.5
# 101338                 22.6                    72.7  ...              58.7
# 101339                 29.0                    84.2  ...              35.3
# 101340                 19.4                    66.9  ...              16.1
#
#         air_quality_PM10  air_quality_us-epa-index  \
# 101336             111.3                         3
# 101337             102.3                         4
# 101338              71.4                         3
# 101339              45.1                         2
# 101340              26.0                         2
#
#         air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 101336                           8  06:42 AM  06:21 PM  01:36 AM  11:43 AM
# 101337                          10  05:39 AM  05:24 PM  12:19 AM  10:55 AM
# 101338                           7  06:27 AM  06:22 PM  12:47 AM  12:17 PM
# 101339                           3  06:33 AM  06:32 PM  12:47 AM  12:35 PM
# 101340                           2  06:21 AM  06:07 PM  01:00 AM  11:42 AM
#
#              moon_phase  moon_illumination
# 101336  Waning Crescent                 46
# 101337  Waning Crescent                 46
# 101338  Waning Crescent                 46
# 101339  Waning Crescent                 46
# 101340  Waning Crescent                 46
#
# [5 rows x 42 columns]

# %%
# no. of rows and no. of columns in the data
data.shape
# Out:
# (101341, 42)

# %%
# columns included in the data
data.columns
# Out:
# Index(['country', 'location_name', 'region', 'latitude', 'longitude',
#        'timezone', 'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
# datatype of each column
data.dtypes
# Out:
# country                          object
# location_name                    object
# region                           object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                     float64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                float64
# uv_index                        float64
# gust_mph                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# sunrise                          object
# sunset                           object
# moonrise                         object
# moonset                          object
# moon_phase                       object
# moon_illumination                 int64
# dtype: object

# %%
# statistical data  of the numerical columns
data.describe().T
# Out:
#                                  count          mean           std  \
# latitude                      101341.0  2.309764e+01  5.791065e+00
# longitude                     101341.0  8.024551e+01  5.762573e+00
# last_updated_epoch            101341.0  1.701463e+09  4.785645e+06
# temperature_celsius           101341.0  1.951635e+01  6.205026e+00
# temperature_fahrenheit        101341.0  6.712949e+01  1.116889e+01
# wind_mph                      101341.0  4.817111e+00  2.688909e+00
# wind_kph                      101341.0  7.757530e+00  4.319181e+00
# wind_degree                   101341.0  1.522521e+02  1.148212e+02
# pressure_mb                   101341.0  1.013012e+03  5.046791e+00
# pressure_in                   101341.0  2.991378e+01  1.489105e-01
# precip_mm                     101341.0  9.539505e-02  6.548974e-01
# precip_in                     101341.0  3.681925e-03  2.578177e-02
# humidity                      101341.0  6.495207e+01  2.195484e+01
# cloud                         101341.0  2.472673e+01  3.046359e+01
# feels_like_celsius            101341.0  2.027834e+01  7.352548e+00
# feels_like_fahrenheit         101341.0  6.849427e+01  1.323414e+01
# visibility_km                 101341.0  8.614344e+00  2.854896e+00
# visibility_miles              101341.0  5.082060e+00  1.867650e+00
# uv_index                      101341.0  1.099841e+00  7.632509e-01
# gust_mph                      101341.0  9.372627e+00  4.736422e+00
# gust_kph                      101341.0  1.508460e+01  7.620431e+00
# air_quality_Carbon_Monoxide   101341.0  8.058363e+02  6.793104e+02
# air_quality_Ozone             101341.0  3.941368e+01  2.869178e+01
# air_quality_Nitrogen_dioxide  101341.0  1.497445e+01  1.588667e+01
# air_quality_Sulphur_dioxide   101341.0  6.307388e+00  1.316479e+01
# air_quality_PM2.5             101341.0  9.950228e+01  1.012007e+02
# air_quality_PM10              101341.0  1.166306e+02  1.143099e+02
# air_quality_us-epa-index      101341.0  3.364097e+00  1.454953e+00
# air_quality_gb-defra-index    101341.0  6.861211e+00  3.520185e+00
# moon_illumination             101341.0  5.257323e+01  3.496142e+01
#
#                                        min           25%           50%  \
# latitude                      7.170000e+00  2.027000e+01  2.395000e+01
# longitude                     6.897000e+01  7.607000e+01  7.869000e+01
# last_updated_epoch            1.693286e+09  1.697231e+09  1.701635e+09
# temperature_celsius          -3.070000e+01  1.600000e+01  2.060000e+01
# temperature_fahrenheit       -2.330000e+01  6.080000e+01  6.900000e+01
# wind_mph                      2.200000e+00  2.700000e+00  4.300000e+00
# wind_kph                      3.600000e+00  4.300000e+00  6.800000e+00
# wind_degree                   1.000000e+00  5.100000e+01  1.140000e+02
# pressure_mb                   9.910000e+02  1.010000e+03  1.014000e+03
# pressure_in                   2.928000e+01  2.984000e+01  2.994000e+01
# precip_mm                     0.000000e+00  0.000000e+00  0.000000e+00
# precip_in                     0.000000e+00  0.000000e+00  0.000000e+00
# humidity                      1.000000e+01  4.600000e+01  6.600000e+01
# cloud                         0.000000e+00  1.000000e+00  9.000000e+00
# feels_like_celsius           -3.650000e+01  1.600000e+01  2.060000e+01
# feels_like_fahrenheit        -3.380000e+01  6.080000e+01  6.900000e+01
# visibility_km                 0.000000e+00  1.000000e+01  1.000000e+01
# visibility_miles              0.000000e+00  6.000000e+00  6.000000e+00
# uv_index                      1.000000e+00  1.000000e+00  1.000000e+00
# gust_mph                      0.000000e+00  6.000000e+00  8.500000e+00
# gust_kph                      0.000000e+00  9.700000e+00  1.370000e+01
# air_quality_Carbon_Monoxide   1.135000e+02  4.273000e+02  6.008000e+02
# air_quality_Ozone             0.000000e+00  1.700000e+01  3.470000e+01
# air_quality_Nitrogen_dioxide  0.000000e+00  5.300000e+00  1.050000e+01
# air_quality_Sulphur_dioxide   0.000000e+00  1.500000e+00  3.200000e+00
# air_quality_PM2.5             5.000000e-01  3.140000e+01  6.710000e+01
# air_quality_PM10              5.000000e-01  4.070000e+01  8.220000e+01
# air_quality_us-epa-index      1.000000e+00  2.000000e+00  4.000000e+00
# air_quality_gb-defra-index    1.000000e+00  3.000000e+00  9.000000e+00
# moon_illumination             0.000000e+00  1.800000e+01  5.400000e+01
#
#                                        75%           max
# latitude                      2.677000e+01  3.457000e+01
# longitude                     8.390000e+01  9.580000e+01
# last_updated_epoch            1.705602e+09  1.709572e+09
# temperature_celsius           2.400000e+01  3.830000e+01
# temperature_fahrenheit        7.520000e+01  1.009000e+02
# wind_mph                      6.000000e+00  2.680000e+01
# wind_kph                      9.700000e+00  4.320000e+01
# wind_degree                   2.670000e+02  3.600000e+02
# pressure_mb                   1.016000e+03  1.073000e+03
# pressure_in                   3.001000e+01  3.169000e+01
# precip_mm                     0.000000e+00  4.380000e+01
# precip_in                     0.000000e+00  1.720000e+00
# humidity                      8.400000e+01  1.000000e+02
# cloud                         4.500000e+01  1.000000e+02
# feels_like_celsius            2.570000e+01  5.050000e+01
# feels_like_fahrenheit         7.820000e+01  1.229000e+02
# visibility_km                 1.000000e+01  1.000000e+01
# visibility_miles              6.000000e+00  6.000000e+00
# uv_index                      1.000000e+00  9.000000e+00
# gust_mph                      1.220000e+01  5.100000e+01
# gust_kph                      1.970000e+01  8.220000e+01
# air_quality_Carbon_Monoxide   9.747000e+02  1.356510e+04
# air_quality_Ozone             5.720000e+01  2.432000e+02
# air_quality_Nitrogen_dioxide  1.950000e+01  3.181000e+02
# air_quality_Sulphur_dioxide   6.500000e+00  5.570000e+02
# air_quality_PM2.5             1.313000e+02  1.374800e+03
# air_quality_PM10              1.527000e+02  1.537800e+03
# air_quality_us-epa-index      4.000000e+00  6.000000e+00
# air_quality_gb-defra-index    1.000000e+01  1.000000e+01
# moon_illumination             8.800000e+01  1.000000e+02

# %%
# information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101341 entries, 0 to 101340
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       101341 non-null  object
#  1   location_name                 101341 non-null  object
#  2   region                        101341 non-null  object
#  3   latitude                      101341 non-null  float64
#  4   longitude                     101341 non-null  float64
#  5   timezone                      101341 non-null  object
#  6   last_updated_epoch            101341 non-null  int64
#  7   last_updated                  101341 non-null  object
#  8   temperature_celsius           101341 non-null  float64
#  9   temperature_fahrenheit        101341 non-null  float64
#  10  condition_text                101341 non-null  object
#  11  wind_mph                      101341 non-null  float64
#  12  wind_kph                      101341 non-null  float64
#  13  wind_degree                   101341 non-null  int64
#  14  wind_direction                101341 non-null  object
#  15  pressure_mb                   101341 non-null  float64
#  16  pressure_in                   101341 non-null  float64
#  17  precip_mm                     101341 non-null  float64
#  18  precip_in                     101341 non-null  float64
#  19  humidity                      101341 non-null  int64
#  20  cloud                         101341 non-null  int64
#  21  feels_like_celsius            101341 non-null  float64
#  22  feels_like_fahrenheit         101341 non-null  float64
#  23  visibility_km                 101341 non-null  float64
#  24  visibility_miles              101341 non-null  float64
#  25  uv_index                      101341 non-null  float64
#  26  gust_mph                      101341 non-null  float64
#  27  gust_kph                      101341 non-null  float64
#  28  air_quality_Carbon_Monoxide   101341 non-null  float64
#  29  air_quality_Ozone             101341 non-null  float64
#  30  air_quality_Nitrogen_dioxide  101341 non-null  float64
#  31  air_quality_Sulphur_dioxide   101341 non-null  float64
#  32  air_quality_PM2.5             101341 non-null  float64
#  33  air_quality_PM10              101341 non-null  float64
#  34  air_quality_us-epa-index      101341 non-null  int64
#  35  air_quality_gb-defra-index    101341 non-null  int64
#  36  sunrise                       101341 non-null  object
#  37  sunset                        101341 non-null  object
#  38  moonrise                      101341 non-null  object
#  39  moonset                       101341 non-null  object
#  40  moon_phase                    101341 non-null  object
#  41  moon_illumination             101341 non-null  int64
# dtypes: float64(23), int64(7), object(12)
# memory usage: 32.5+ MB

# %%
# to find missing values
data.isna().sum()
# data.dropna(inplace=True)
# if missing value in numeric column fill by mean or median
# if missing value in object column fill by mode
# Out:
# country                         0
# location_name                   0
# region                          0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# sunset                          0
# moonrise                        0
# moonset                         0
# moon_phase                      0
# moon_illumination               0
# dtype: int64

# %% [markdown]
# DATA PREPROCESSING STEPS

# %%
# to find unique values in the column 'condition_text'
print(data['condition_text'].nunique())
data['condition_text'].unique()
# Out:
# 49
# array(['Partly cloudy', 'Sunny', 'Cloudy', 'Mist', 'Patchy rain possible',
#        'Overcast', 'Patchy light rain with thunder', 'Light rain shower',
#        'Moderate or heavy rain shower', 'Clear', 'Light rain',
#        'Torrential rain shower', 'Fog', 'Thundery outbreaks possible',
#        'Patchy light drizzle', 'Moderate rain', 'Patchy light rain',
#        'Moderate rain at times', 'Heavy rain', 'Heavy rain at times',
#        'Light drizzle', 'Moderate or heavy rain with thunder',
#        'Patchy snow possible', 'Moderate or heavy snow showers',
#        'Light snow showers', 'Moderate or heavy snow with thunder',
#        'Patchy light snow with thunder', 'Light sleet',
#        'Light freezing rain', 'Patchy light snow', 'Patchy moderate snow',
#        'Light snow', 'Moderate snow', 'Overcast ', 'Clear ', 'Cloudy ',
#        'Partly Cloudy ', 'Patchy rain nearby',
#        'Thundery outbreaks in nearby', 'Heavy snow',
#        'Patchy light snow in area with thunder',
#        'Patchy light rain in area with thunder', 'Light sleet showers',
#        'Moderate or heavy snow in area with thunder',
#        'Moderate or heavy rain in area with thunder', 'Patchy heavy snow',
#        'Patchy snow nearby', 'Patchy sleet nearby',
#        'Moderate or heavy sleet'], dtype=object)

# %%
# there are 49 different values in this column, need to standardize these values
data['condition_text']=[i.lower() for i in data['condition_text']]
data['condition_text']
# Out:
# 0         partly cloudy
# 1                 sunny
# 2         partly cloudy
# 3                cloudy
# 4                cloudy
#               ...
# 101336             mist
# 101337           clear
# 101338           clear
# 101339             mist
# 101340           clear
# Name: condition_text, Length: 101341, dtype: object

# %%
data['condition_text']=data['condition_text'].str.replace('cloudy ','cloudy')
data['condition_text']=data['condition_text'].str.replace('clear ','clear')

# %%
print(data['condition_text'].value_counts())
# Out:
# condition_text
# clear                                          59481
# mist                                           14167
# partly cloudy                                  10256
# patchy rain possible                            5126
# light rain shower                               2840
# fog                                             2005
# overcast                                        1664
# cloudy                                          1540
# patchy rain nearby                               824
# sunny                                            772
# light rain                                       461
# moderate or heavy rain shower                    395
# light drizzle                                    259
# patchy light drizzle                             214
# moderate or heavy rain with thunder              206
# overcast                                         183
# moderate rain                                    169
# patchy light rain                                138
# moderate rain at times                            78
# patchy light rain with thunder                    75
# thundery outbreaks possible                       69
# heavy rain                                        57
# light freezing rain                               57
# moderate or heavy snow showers                    38
# torrential rain shower                            34
# heavy snow                                        30
# patchy light rain in area with thunder            29
# light snow showers                                27
# patchy snow nearby                                20
# patchy light snow                                 20
# thundery outbreaks in nearby                      18
# light sleet                                       15
# light snow                                        12
# patchy moderate snow                              12
# moderate or heavy snow in area with thunder        9
# patchy light snow with thunder                     6
# patchy snow possible                               5
# light sleet showers                                5
# patchy heavy snow                                  5
# moderate or heavy sleet                            5
# heavy rain at times                                4
# patchy light snow in area with thunder             4
# patchy sleet nearby                                3
# moderate snow                                      2
# moderate or heavy snow with thunder                1
# moderate or heavy rain in area with thunder        1
# Name: count, dtype: int64

# %%
from itertools import chain
# it takes multiple iterables and returns an iterator that produces elements from the first iterable until it's exhausted,
# then it continues with the next iterable, until all of the iterables are exhausted.
def create_list(x):
  list1=[w.split() for w in x.split(',')]
  # This is a list comprehension that iterates over each substring produced by splitting x by commas.
  # For each substring w, it further splits w by whitespace, creating a list of words.
  list2=list(chain(*list1))
  # This converts the flattened iterator produced by chain back into a list.
  return list2

# %%
# the 49 categories converted into 4 by following
def get_list(list3):
  if 'clear' in list3 or 'sunny' in list3:
    return 'CLEAR'
  elif 'mist' in list3 or 'fog' in list3 or 'snow' in list3:
    return 'MISTY'
  elif 'cloudy' in list3 or 'overcast' in list3:
    return 'CLOUDY'
  else:
    return 'RAINY'

# %%
# the column 'condition_text' is rename as weather with 4 unique categories
data['weather']=data['condition_text'].apply(lambda x:get_list(create_list(x)))
data['weather']
# Out:
# 0         CLOUDY
# 1          CLEAR
# 2         CLOUDY
# 3         CLOUDY
# 4         CLOUDY
#            ...
# 101336     MISTY
# 101337     CLEAR
# 101338     CLEAR
# 101339     MISTY
# 101340     CLEAR
# Name: weather, Length: 101341, dtype: object

# %%
print(data['weather'].value_counts())
# Out:
# weather
# CLEAR     60253
# MISTY     16363
# CLOUDY    13643
# RAINY     11082
# Name: count, dtype: int64

# %%
# there is a huge difference for 'CLEAR', to balance the categories select 11000 samples randomly
clear_df=data[data['weather']=='CLEAR'].sample(n=11000)
misty_df=data[data['weather']=='MISTY'].sample(n=11000)
cloudy_df=data[data['weather']=='CLOUDY'].sample(n=11000)
rainy_df=data[data['weather']=='RAINY'].sample(n=11000)

# %%
# now it become balanced
new_data=pd.concat([clear_df,misty_df,cloudy_df,rainy_df],axis=0,ignore_index=True)
new_data
# Out:
#       country location_name          region  latitude  longitude  \
# 0       India      Dehradun     Uttarakhand     30.32      78.03
# 1       India  Chittaurgarh       Rajasthan     24.88      74.63
# 2       India     Madhubani           Bihar     26.37      86.08
# 3       India         Satna  Madhya Pradesh     24.58      80.83
# 4       India         Jalor       Rajasthan     25.35      72.62
# ...       ...           ...             ...       ...        ...
# 43995   India     Balrampur   Uttar Pradesh     27.43      82.18
# 43996   India        Nirmal  Andhra Pradesh     19.10      78.35
# 43997   India      Dhamtari    Chhattisgarh     20.71      81.55
# 43998   India        Almora     Uttarakhand     29.62      79.67
# 43999   India      Tuensang        Nagaland     26.28      94.83
#
#            timezone  last_updated_epoch      last_updated  \
# 0      Asia/Kolkata          1697921100  2023-10-22 02:15
# 1      Asia/Kolkata          1706896800  2024-02-02 23:30
# 2      Asia/Kolkata          1708881300  2024-02-25 22:45
# 3      Asia/Kolkata          1709571600  2024-03-04 22:30
# 4      Asia/Kolkata          1708708500  2024-02-23 22:45
# ...             ...                 ...               ...
# 43995  Asia/Kolkata          1695249000  2023-09-21 04:00
# 43996  Asia/Kolkata          1701027900  2023-11-27 01:15
# 43997  Asia/Kolkata          1701200700  2023-11-29 01:15
# 43998  Asia/Kolkata          1694214000  2023-09-09 04:30
# 43999  Asia/Kolkata          1695852000  2023-09-28 03:30
#
#        temperature_celsius  temperature_fahrenheit  ... air_quality_PM10  \
# 0                     14.5                    58.2  ...            104.7
# 1                     16.4                    61.5  ...             74.3
# 2                     16.6                    61.9  ...            179.6
# 3                     18.8                    65.8  ...             28.8
# 4                     18.8                    65.8  ...             61.4
# ...                    ...                     ...  ...              ...
# 43995                 24.2                    75.5  ...             33.3
# 43996                 24.1                    75.3  ...             43.9
# 43997                 17.7                    63.8  ...            161.6
# 43998                 20.0                    68.0  ...             38.1
# 43999                 20.5                    69.0  ...             20.9
#
#        air_quality_us-epa-index  air_quality_gb-defra-index   sunrise  \
# 0                             4                          10  06:23 AM
# 1                             3                           5  07:14 AM
# 2                             4                          10  06:14 AM
# 3                             2                           2  06:26 AM
# 4                             2                           4  07:09 AM
# ...                         ...                         ...       ...
# 43995                         2                           3  05:49 AM
# 43996                         3                           5  06:30 AM
# 43997                         5                          10  06:21 AM
# 43998                         2                           3  05:52 AM
# 43999                         2                           2  05:01 AM
#
#          sunset     moonrise   moonset       moon_phase  moon_illumination  \
# 0      05:41 PM     12:47 PM  10:50 PM  Waxing Crescent                 37
# 1      06:16 PM  No moonrise  11:23 AM     Last Quarter                 59
# 2      05:44 PM     06:30 PM  06:44 AM   Waning Gibbous                100
# 3      06:11 PM     01:10 AM  11:42 AM  Waning Crescent                 46
# 4      06:38 PM     05:43 PM  06:35 AM   Waxing Gibbous                 98
# ...         ...          ...       ...              ...                ...
# 43995  06:01 PM     10:22 AM  09:04 PM  Waxing Crescent                 22
# 43996  05:37 PM     04:44 PM  05:15 AM   Waxing Gibbous                 98
# 43997  05:22 PM     06:06 PM  07:08 AM   Waning Gibbous                 99
# 43998  06:26 PM  No moonrise  02:21 PM  Waning Crescent                 39
# 43999  05:02 PM     03:52 PM  02:21 AM   Waxing Gibbous                 91
#
#        weather
# 0        CLEAR
# 1        CLEAR
# 2        CLEAR
# 3        CLEAR
# 4        CLEAR
# ...        ...
# 43995    RAINY
# 43996    RAINY
# 43997    RAINY
# 43998    RAINY
# 43999    RAINY
#
# [44000 rows x 43 columns]

# %%
print(new_data.shape)
new_data['weather'].unique()
# Out:
# (44000, 43)
# array(['CLEAR', 'MISTY', 'CLOUDY', 'RAINY'], dtype=object)

# %%
new_data['weather'].value_counts()
# Out:
# weather
# CLEAR     11000
# MISTY     11000
# CLOUDY    11000
# RAINY     11000
# Name: count, dtype: int64

# %%
# To visualize the part of each
p=['MISTY','CLEAR','CLOUDY','RAINY']
q=[11000,11000,11000,11000]
plt.pie(q,labels=p,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
# map each categories into 0,1,2 and 3
new_data['weather']=new_data['weather'].map({'MISTY':0,'CLEAR':1,'CLOUDY':2,'RAINY':3})

# %% [markdown]
# OBJECT COLUMNS

# %%
new_data['country'].unique()
# since it has only one value it doesn't affect the output, so can drop this column
# Out:
# array(['India'], dtype=object)

# %%
# to find unique values in 'loaction_name'
new_data['location_name'].unique()
# since there are many values, it can't give perfection to the model
# Out:
# array(['Dehradun', 'Chittaurgarh', 'Madhubani', 'Satna', 'Jalor',
#        'Champawat', 'Bidar', 'North Gauhati', 'Harda', 'Bhagalpur',
#        'Lalitpur', 'Yamunanagar', 'Alwar', 'Jhargram', 'Jhabua', 'Dadra',
#        'Rampur', 'Pendra', 'Jalaun', 'Udaipur', 'Gopalganj', 'Imphal',
#        'Buldana', 'Narayanpet', 'Yavatmal', 'Hoshangabad', 'Aligarh',
#        'Dhule', 'Biswanath', 'Gariaband', 'Jalpaiguri', 'Khargone',
#        'Jamnagar', 'Karimganj', 'Surguja', 'Churu', 'Rajgarh', 'Muktsar',
#        'Shahdol', 'Kupwara', 'Serchhip', 'Bahraich', 'Baramula',
#        'Somnath', 'Saitual', 'Hisar', 'Hardwar', 'Jalgaon', 'Bhojpur',
#        'Una', 'Tonk', 'Bastar', 'Mathura', 'Thoubal', 'Mainpuri',
#        'Ramban', 'Bhavnagar', 'Faizabad', 'Balod', 'Barjala', 'Tuensang',
#        'Dharwad', 'Washim', 'Morbi', 'Raisen', 'Karur', 'Bharatpur',
#        'Meerut', 'Vadodara', 'Jaisalmer', 'Shivpuri', 'Belgaum', 'Bokaro',
#        'Banswara', 'Nagaur', 'Bhilwara', 'Mau', 'Nizamabad', 'Bundi',
#        'Tirunelveli', 'Rohtak', 'Anantnag', 'Gulbarga', 'Shupiyan',
#        'Pali', 'Kannauj', 'Moradabad', 'Bulandshahr', 'Bhadrak',
#        'Fazilka', 'Surat', 'Korba', 'Mahasamund', 'Surendranagar',
#        'Jamtara', 'Raichur', 'Pithoragarh', 'Hamirpur', 'Porbandar',
#        'Latur', 'Bargarh', 'Etawah', 'Murshidabad', 'Bongaigaon',
#        'Dhemaji', 'Kheri', 'Baksa Duar', 'Latehar', 'Mahendragarh',
#        'Bhind', 'Bankura', 'Dhanbad', 'Almora', 'Tirap', 'Adilabad',
#        'Shajapur', 'Fatehabad', 'Gurdaspur', 'Ghazipur', 'Mahe',
#        'Gwalior', 'Lawngtlai', 'Guna', 'Pathanamthitta', 'Suryapet',
#        'Jorhat', 'Nellore', 'Tumkur', 'Samastipur', 'Rewa', 'Panipat',
#        'Sant', 'Barwani', 'Morena', 'Bid', 'Chandel', 'Karnal',
#        'South Salmara', 'Moga', 'Tikamgarh', 'Goalpara', 'Sambalpur',
#        'Chhatarpur', 'Barddhaman', 'Jodhpur', 'Talab Data', 'Hardoi',
#        'Yadgir', 'Maldah', 'Sagar', 'Deoria', 'Koch Bihar',
#        'Muzaffarnagar', 'Wanaparthy', 'Varanasi', 'Dhar', 'Garhwal',
#        'Simdega', 'Amreli', 'Chandigarh', 'Srinagar', 'Narsimhapur',
#        'Pulwama', 'Panna', 'Thiruvarur', 'Kargil', 'Barnala', 'Balangir',
#        'Jhansi', 'Gonda', 'Mon', 'Banka', 'Kodarma', 'Agra', 'Dibrugarh',
#        'Yanam', 'Siang', 'Koppal', 'Chhindwara', 'Karauli', 'Shimoga',
#        'Kangpokpi', 'Dohad', 'Jind', 'Kathua', 'Araria', 'Uttarkashi',
#        'Peddapalli', 'Majuli', 'Tamenglong', 'Bhandara', 'Golaghat',
#        'Lohardaga', 'Nagapattinam', 'Aizawl', 'Dindori', 'Basti', 'Daman',
#        'Jabalpur', 'Osmanabad', 'Balaghat', 'Salem', 'Chandrapur',
#        'Jhunjhunun', 'Solan', 'Baran', 'Jharsuguda', 'Jhalawar',
#        'Hingoli', 'Mahoba', 'Gorakhpur', 'Tehri-Garhwal', 'Bhadohi',
#        'Ambala', 'Durg', 'Dhubri', 'Visakhapatnam', 'Doda', 'Jamui',
#        'Amethi', 'Dungarpur', 'Nalgonda', 'Bijapur', 'Ajmer', 'Sitapur',
#        'Hanumangarh', 'Sirmaur', 'Datia', 'Saran', 'Khandwa',
#        'Nandi Hills', 'Allahabad', 'Bhabua', 'Pilibhit', 'Amravati',
#        'Chandauli', 'Sahibganj', 'Mahamaya', 'Kondagaon', 'Dharmapuri',
#        'Narayanpur', 'Buxar', 'Dharmanagar', 'Malkangiri', 'Erode',
#        'Ashoknagar', 'Lakhisarai', 'Shimla', 'Faridkot', 'Hojai',
#        'Chittoor', 'Nadia', 'Seoni', 'Giridih', 'Nayagarh', 'Raipur',
#        'Sikar', 'Neemuch', 'Mahesana', 'Khammam', 'Dhaulpur', 'Bageshwar',
#        'Kapurthala', 'Nanded', 'Auraiya', 'East Godavari', 'Vidisha',
#        'Parbhani', 'Sitamarhi', 'Krishnagiri', 'Darbhanga', 'Betul',
#        'Pratapgarh', 'Kanpur', 'Banda', 'Jangaon', 'Leh', 'Kulgam',
#        'Saiha', 'Nandurbar', 'Aurangabad', 'Kangra', 'Sheopur',
#        'Begusarai', 'Siddipet', 'Vellore', 'Mancherial', 'Bilaspur',
#        'Dimapur', 'Ganderbal', 'Nirmal', 'Siwan', 'Bikaner',
#        'Chikmagalur', 'Palghar', 'Bareilly', 'Barmer', 'Medak',
#        'Sundargarh', 'Deoghar', 'Warangal', 'Churachandpur', 'Kottayam',
#        'Buddha Gaya', 'Nagar', 'Garhwa', 'Rudraprayag', 'Ludhiana',
#        'Darjiling', 'Sirohi', 'Nawada', 'Chamoli', 'Shahjahanpur',
#        'Muzaffarpur', 'Dhamtari', 'Agar', 'Ahmadnagar', 'Sawai Madhopur',
#        'Azamgarh', 'Saharanpur', 'Mokokchung', 'Dhalai', 'Firozabad',
#        'Nagaon', 'Purnia', 'Sultanpur', 'Lunglei', 'Gadag', 'Rajkot',
#        'Sheohar', 'Lakhimpur', 'Barpeta', 'Diu', 'Solapur', 'Kakching',
#        'Balrampur', 'Punch', 'Raigarh', 'Kishanganj', 'Ganjam',
#        'Baleshwar', 'Mysore', 'Ratnagiri', 'Kannur', 'Mungeli',
#        'Rajsamand', 'Etah', 'Damoh', 'Janjgir', 'Kolhapur', 'Anand',
#        'Sangli', 'Wokha', 'Haveri', 'Anuppur', 'Farrukhabad', 'Samba',
#        'Patan', 'Kurnool', 'Pune', 'Hoshiarpur', 'Surajpur', 'Mandi',
#        'Kota', 'Chitradurga', 'Phek', 'Ballia', 'Saraikela', 'Udupi',
#        'Sidhi', 'Khordha', 'Umaria', 'Karimnagar', 'Puruliya', 'Gumla',
#        'Chamba', 'Kendrapara', 'Guntur', 'Srikakulam', 'Jaunpur',
#        'Pathankot', 'Darrang', 'Kasaragod', 'Navsari', 'Tawang', 'Jalna',
#        'Khowai', 'Koraput', 'Mirzapur', 'Ratlam', 'Satara', 'Sukma',
#        'Mansa', 'Anantapur', 'Sehore', 'Bhopal', 'Indore', 'Fatehpur',
#        'Burhanpur', 'Udhampur', 'Bhiwani', 'Alirajpur', 'Anugul',
#        'Jagtial', 'Khagaria', 'Jashpur', 'Baudh', 'Namakkal', 'Zunheboto',
#        'Saharsa', 'Mandya', 'Fatehgarh Sahib', 'Kaithal', 'Hapur',
#        'Supaul', 'Hailakandi', 'Jammu', 'Mayurbhanj', 'Mandsaur',
#        'Dwarka', 'Rupnagar', 'Junagadh', 'Rayagada', 'Vikarabad',
#        'Ganganagar', 'Valsad', 'Mamit', 'Kolar', 'Sirsa',
#        'Upper Tirupati', 'Firozpur', 'Kanker', 'Rae Bareli', 'Kokrajhar',
#        'Katihar', 'Baloda Bazar', 'Bharuch', 'Cuddalore', 'Sheikhpura',
#        'Rewari', 'Medinipur', 'Tiruvannamalai', 'Sangrur', 'Munger',
#        'Dumka', 'Hassan', 'Kohima', 'Godda', 'Udalguri', 'Krishna',
#        'Kishtwar', 'Jalandhar', 'Bijnor', 'Bellary', 'Ramgarh',
#        'Hazaribagh', 'Patiala', 'Tinsukia', 'Kollam', 'Puducherry',
#        'Budaun', 'Goa', 'Karaikal', 'Kavaratti', 'West Godavari',
#        'Madurai', 'Bagalkot', 'Khunti', 'Alipur', 'Sambhal',
#        'Ramanathapuram', 'Puri District', 'Mandla', 'Tiruchirappalli',
#        'Ranipet', 'Akola', 'Ukhrul', 'Sivaganga', 'Badgam', 'Kadapa',
#        'Puri', 'Thane', 'Kanniyakumari', 'Sonipat', 'Katni', 'Patna',
#        'Unnao', 'Nalbari', 'Ujjain', 'Chatra', 'Jagatsinghapur',
#        'Gurgaon', 'Bishnupur', 'Alappuzha', 'Cuttack', 'Vizianagaram',
#        'Ranchi', 'Amritsar', 'Gaya', 'Tenkasi', 'Dewas', 'Kantha',
#        'Arwal', 'Arong', 'Baghpat', 'Rangachang', 'Jhajjar', 'Malappuram',
#        'Enounga', 'Palwal', 'Kolkata', 'Laful', 'Ghaziabad', 'Moshoit',
#        'Medchal', 'Dindigul', 'Bangalore', 'Geinyale', 'Nagpur',
#        'Kancheepuram', 'Dhenkanal', 'Pudukkottai', 'Thanjavur', 'Hugli',
#        'Ariyalur', 'Kheda', 'Niwari', 'Chennai', 'Shahdara', 'Coimbatore',
#        'Wardha', 'Palakkad', 'Bara Banki', 'Tarn Taran', 'Thrissur',
#        'Faridabad', 'South Suburban', 'Thiruvananthapuram', 'Haora',
#        'Dausa', 'Tiruppur', 'Perambalur', 'Kozhikode', 'Lucknow',
#        'Gandhinagar', 'New Delhi', 'Mumbai', 'Jaipur', 'Idukki',
#        'Ernakulam', 'Calcutta', 'North Guwahati'], dtype=object)

# %%
# to find unique values in 'region'
new_data['region'].unique()
# Out:
# array(['Uttarakhand', 'Rajasthan', 'Bihar', 'Madhya Pradesh', 'Karnataka',
#        'Assam', 'Uttar Pradesh', 'Haryana', 'West Bengal',
#        'Dadra and Nagar Haveli', 'Maharashtra', 'Orissa', 'Manipur',
#        'Andhra Pradesh', 'Chhattisgarh', 'Gujarat', 'Punjab',
#        'Jammu and Kashmir', 'Mizoram', 'Tripura', 'Nagaland',
#        'Tamil Nadu', 'Jharkhand', 'Arunachal Pradesh', 'Kerala', 'Goa',
#        'Chandigarh', 'Daman and Diu', 'Himachal Pradesh', 'Puducherry',
#        'Lakshadweep', 'Andaman and Nicobar Islands', 'Delhi'],
#       dtype=object)

# %%
# 'region' counts and its graphical representation
print(new_data['region'].value_counts())
new_data['region'].value_counts().plot(kind='bar')
# Out:
# region
# Uttar Pradesh                  4280
# Tamil Nadu                     3358
# Madhya Pradesh                 3343
# Andhra Pradesh                 2801
# Maharashtra                    2568
# Orissa                         2288
# Rajasthan                      2174
# Bihar                          2173
# Karnataka                      2152
# Assam                          1883
# West Bengal                    1883
# Kerala                         1761
# Chhattisgarh                   1645
# Jharkhand                      1557
# Gujarat                        1487
# Jammu and Kashmir              1444
# Haryana                        1420
# Punjab                         1303
# Manipur                         753
# Uttarakhand                     649
# Nagaland                        593
# Mizoram                         582
# Himachal Pradesh                344
# Puducherry                      275
# Delhi                           242
# Tripura                         200
# Goa                             189
# Arunachal Pradesh               168
# Andaman and Nicobar Islands     144
# Daman and Diu                   119
# Lakshadweep                     104
# Dadra and Nagar Haveli           62
# Chandigarh                       56
# Name: count, dtype: int64
# <Axes: xlabel='region'>

# %%
# to find unique values in the column 'timezone'
new_data['timezone'].unique()
# Out:
# array(['Asia/Kolkata', 'Asia/Dhaka', 'Asia/Karachi'], dtype=object)

# %%
# 'timezone' counts and its graphical representation
print(new_data['timezone'].value_counts())
new_data['timezone'].value_counts().plot(kind='bar')
# Out:
# timezone
# Asia/Kolkata    43781
# Asia/Dhaka        156
# Asia/Karachi       63
# Name: count, dtype: int64
# <Axes: xlabel='timezone'>

# %%
# to find unique values in the column 'wind_direction'
new_data['wind_direction'].unique()
# Out:
# array(['NE', 'E', 'NNW', 'W', 'N', 'NW', 'WSW', 'ESE', 'SE', 'WNW', 'NNE',
#        'SSE', 'ENE', 'S', 'SW', 'SSW'], dtype=object)

# %%
# 'wind_direction' counts and its graphical representation
print(new_data['wind_direction'].value_counts())
new_data['wind_direction'].value_counts().plot(kind='bar')
# Out:
# wind_direction
# N      5423
# ENE    4531
# NE     4135
# E      4054
# NNE    3371
# ESE    2891
# W      2704
# WSW    2430
# WNW    2381
# NW     2259
# NNW    2237
# SE     2205
# SW     1469
# SSW    1345
# SSE    1315
# S      1250
# Name: count, dtype: int64
# <Axes: xlabel='wind_direction'>

# %%
# to find unique values in the column 'moon_phase'
new_data['moon_phase'].unique()
# Out:
# array(['Waxing Crescent', 'Last Quarter', 'Waning Gibbous',
#        'Waning Crescent', 'Waxing Gibbous', 'New Moon', 'Full Moon',
#        'First Quarter'], dtype=object)

# %%
# 'moon_phase' counts and its graphical representation
print(new_data['moon_phase'].value_counts())
new_data['moon_phase'].value_counts().plot(kind='bar')
# Out:
# moon_phase
# Waning Gibbous     10739
# Waning Crescent     9162
# Waxing Crescent     8617
# Waxing Gibbous      8592
# Full Moon           2052
# Last Quarter        1779
# New Moon            1695
# First Quarter       1364
# Name: count, dtype: int64
# <Axes: xlabel='moon_phase'>

# %%
# object datatype column converted into datetime format
new_data['last_updated']=pd.to_datetime(new_data['last_updated'])
new_data['last_updated']
# Out:
# 0       2023-10-22 02:15:00
# 1       2024-02-02 23:30:00
# 2       2024-02-25 22:45:00
# 3       2024-03-04 22:30:00
# 4       2024-02-23 22:45:00
#                 ...
# 43995   2023-09-21 04:00:00
# 43996   2023-11-27 01:15:00
# 43997   2023-11-29 01:15:00
# 43998   2023-09-09 04:30:00
# 43999   2023-09-28 03:30:00
# Name: last_updated, Length: 44000, dtype: datetime64[ns]

# %%
# categorized using month, since weather always
new_data['last_updated']=new_data['last_updated'].dt.month
new_data['last_updated']
# Out:
# 0        10
# 1         2
# 2         2
# 3         3
# 4         2
#          ..
# 43995     9
# 43996    11
# 43997    11
# 43998     9
# 43999     9
# Name: last_updated, Length: 44000, dtype: int32

# %%
# to delete string from the time format hh:mm
new_data['sunrise']=new_data['sunrise'].str.replace(' AM','')
new_data['sunset']=new_data['sunset'].str.replace(' PM','')
new_data['moonrise']=new_data['moonrise'].str.replace(' PM','')
new_data['moonrise']=new_data['moonrise'].str.replace(' AM','')
new_data['moonrise']=new_data['moonrise'].str.replace('No moonrise','00:00')
new_data['moonset']=new_data['moonset'].str.replace(' AM','')
new_data['moonset']=new_data['moonset'].str.replace(' PM','')
new_data['moonset']=new_data['moonset'].str.replace('No moonset','00:00')

# %%
# hh:mm convert into hours, so it changes its datatype as float
new_data['sunrise']=pd.to_datetime(new_data['sunrise'])
new_data['sunrise']=((new_data['sunrise'].dt.hour)+(1/60*(new_data['sunrise'].dt.minute)))
new_data['sunrise']
# Out:
# <ipython-input-96-ea36d5288426>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_data['sunrise']=pd.to_datetime(new_data['sunrise'])
# 0        6.383333
# 1        7.233333
# 2        6.233333
# 3        6.433333
# 4        7.150000
#            ...
# 43995    5.816667
# 43996    6.500000
# 43997    6.350000
# 43998    5.866667
# 43999    5.016667
# Name: sunrise, Length: 44000, dtype: float64

# %%
new_data['sunset']=pd.to_datetime(new_data['sunset'])
new_data['sunset']=((new_data['sunset'].dt.hour)+(1/60*(new_data['sunset'].dt.minute)))
new_data['sunset']
# Out:
# <ipython-input-97-2b1d421928f2>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_data['sunset']=pd.to_datetime(new_data['sunset'])
# 0        5.683333
# 1        6.266667
# 2        5.733333
# 3        6.183333
# 4        6.633333
#            ...
# 43995    6.016667
# 43996    5.616667
# 43997    5.366667
# 43998    6.433333
# 43999    5.033333
# Name: sunset, Length: 44000, dtype: float64

# %%
new_data['moonrise']=pd.to_datetime(new_data['moonrise'])
new_data['moonrise']=((new_data['moonrise'].dt.hour)+(1/60*(new_data['moonrise'].dt.minute)))
new_data['moonrise']
# Out:
# <ipython-input-98-b4a1ed35edef>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_data['moonrise']=pd.to_datetime(new_data['moonrise'])
# 0        12.783333
# 1         0.000000
# 2         6.500000
# 3         1.166667
# 4         5.716667
#            ...
# 43995    10.366667
# 43996     4.733333
# 43997     6.100000
# 43998     0.000000
# 43999     3.866667
# Name: moonrise, Length: 44000, dtype: float64

# %%
new_data['moonset']=pd.to_datetime(new_data['moonset'])
new_data['moonset']=((new_data['moonset'].dt.hour)+(1/60*(new_data['moonset'].dt.minute)))
new_data['moonset']
# Out:
# <ipython-input-99-55ebb45822dd>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_data['moonset']=pd.to_datetime(new_data['moonset'])
# 0        10.833333
# 1        11.383333
# 2         6.733333
# 3        11.700000
# 4         6.583333
#            ...
# 43995     9.066667
# 43996     5.250000
# 43997     7.133333
# 43998     2.350000
# 43999     2.350000
# Name: moonset, Length: 44000, dtype: float64

# %%
# to check datatype
new_data.dtypes
# Out:
# country                          object
# location_name                    object
# region                           object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                      int32
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                     float64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                float64
# uv_index                        float64
# gust_mph                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# sunrise                         float64
# sunset                          float64
# moonrise                        float64
# moonset                         float64
# moon_phase                       object
# moon_illumination                 int64
# weather                           int64
# dtype: object

# %%
# to detect the presence of outliers
sns.boxplot(x='temperature_fahrenheit',y='weather',data=new_data)
# Out:
# <Axes: xlabel='temperature_fahrenheit', ylabel='weather'>

# %%
sns.boxplot(x='wind_degree',y='weather',data=new_data)
# Out:
# <Axes: xlabel='wind_degree', ylabel='weather'>

# %%
sns.boxplot(x='pressure_mb',y='weather',data=new_data)
# Out:
# <Axes: xlabel='pressure_mb', ylabel='weather'>

# %%
sns.boxplot(x='humidity',y='weather',data=new_data)
# Out:
# <Axes: xlabel='humidity', ylabel='weather'>

# %%
sns.boxplot(x='cloud',y='weather',data=new_data)
# Out:
# <Axes: xlabel='cloud', ylabel='weather'>

# %%
sns.boxplot(x='air_quality_us-epa-index',y='weather',data=new_data)
# Out:
# <Axes: xlabel='air_quality_us-epa-index', ylabel='weather'>

# %%
sns.boxplot(x='air_quality_gb-defra-index',y='weather',data=new_data)
# Out:
# <Axes: xlabel='air_quality_gb-defra-index', ylabel='weather'>

# %%
sns.boxplot(x='moon_illumination',y='weather',data=new_data)
# Out:
# <Axes: xlabel='moon_illumination', ylabel='weather'>

# %%
# To detect and remove outliers
def outlier_det(new_data,i):
  Q1=np.percentile(new_data[i],25)
  Q3=np.percentile(new_data[i],75)
  lower=Q1-(1.5*(Q3-Q1))
  upper=Q3+(1.5*(Q3-Q1))
  new_data=new_data[(lower<new_data[i]) & (new_data[i]<upper)]
  return new_data

# %%
lst=['temperature_fahrenheit','wind_degree','pressure_mb','humidity','cloud','air_quality_us-epa-index','moon_illumination']
for i in lst:
  new_data=outlier_det(new_data,i)

# %%
new_data.shape
# Out:
# (42826, 43)

# %%
new_data['weather'].value_counts()
# Out:
# weather
# 0    10836
# 3    10739
# 2    10688
# 1    10563
# Name: count, dtype: int64

# %%
# to drop unwanted columns
new_data.drop(['country','location_name','timezone','condition_text'],axis=1,inplace=True)
new_data.head()
# Out:
#            region  latitude  longitude  last_updated_epoch  last_updated  \
# 0     Uttarakhand     30.32      78.03          1697921100            10
# 1       Rajasthan     24.88      74.63          1706896800             2
# 2           Bihar     26.37      86.08          1708881300             2
# 3  Madhya Pradesh     24.58      80.83          1709571600             3
# 5     Uttarakhand     29.33      80.10          1701719100            12
#
#    temperature_celsius  temperature_fahrenheit  wind_mph  wind_kph  \
# 0                 14.5                    58.2       5.1       8.3
# 1                 16.4                    61.5       2.9       4.7
# 2                 16.6                    61.9       8.1      13.0
# 3                 18.8                    65.8       6.3      10.1
# 5                 11.4                    52.5       5.4       8.6
#
#    wind_degree  ... air_quality_PM10  air_quality_us-epa-index  \
# 0           37  ...            104.7                         4
# 1           89  ...             74.3                         3
# 2          340  ...            179.6                         4
# 3          337  ...             28.8                         2
# 5          358  ...             26.0                         2
#
#    air_quality_gb-defra-index   sunrise    sunset   moonrise    moonset  \
# 0                          10  6.383333  5.683333  12.783333  10.833333
# 1                           5  7.233333  6.266667   0.000000  11.383333
# 2                          10  6.233333  5.733333   6.500000   6.733333
# 3                           2  6.433333  6.183333   1.166667  11.700000
# 5                           2  6.800000  5.183333  11.483333  12.183333
#
#         moon_phase  moon_illumination  weather
# 0  Waxing Crescent                 37        1
# 1     Last Quarter                 59        1
# 2   Waning Gibbous                100        1
# 3  Waning Crescent                 46        1
# 5   Waning Gibbous                 62        1
#
# [5 rows x 39 columns]

# %%
# encoded the object columns using get_dummies
data1=pd.get_dummies(new_data[['region','wind_direction','moon_phase']],drop_first=True)
data1
# Out:
#        region_Andhra Pradesh  region_Arunachal Pradesh  region_Assam  \
# 0                      False                     False         False
# 1                      False                     False         False
# 2                      False                     False         False
# 3                      False                     False         False
# 5                      False                     False         False
# ...                      ...                       ...           ...
# 43995                  False                     False         False
# 43996                   True                     False         False
# 43997                  False                     False         False
# 43998                  False                     False         False
# 43999                  False                     False         False
#
#        region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 0             False              False                False
# 1             False              False                False
# 2              True              False                False
# 3             False              False                False
# 5             False              False                False
# ...             ...                ...                  ...
# 43995         False              False                False
# 43996         False              False                False
# 43997         False              False                 True
# 43998         False              False                False
# 43999         False              False                False
#
#        region_Dadra and Nagar Haveli  region_Daman and Diu  region_Delhi  \
# 0                              False                 False         False
# 1                              False                 False         False
# 2                              False                 False         False
# 3                              False                 False         False
# 5                              False                 False         False
# ...                              ...                   ...           ...
# 43995                          False                 False         False
# 43996                          False                 False         False
# 43997                          False                 False         False
# 43998                          False                 False         False
# 43999                          False                 False         False
#
#        region_Goa  ...  wind_direction_W  wind_direction_WNW  \
# 0           False  ...             False               False
# 1           False  ...             False               False
# 2           False  ...             False               False
# 3           False  ...             False               False
# 5           False  ...             False               False
# ...           ...  ...               ...                 ...
# 43995       False  ...             False               False
# 43996       False  ...             False               False
# 43997       False  ...             False               False
# 43998       False  ...             False               False
# 43999       False  ...             False               False
#
#        wind_direction_WSW  moon_phase_Full Moon  moon_phase_Last Quarter  \
# 0                   False                 False                    False
# 1                   False                 False                     True
# 2                   False                 False                    False
# 3                   False                 False                    False
# 5                   False                 False                    False
# ...                   ...                   ...                      ...
# 43995               False                 False                    False
# 43996               False                 False                    False
# 43997               False                 False                    False
# 43998               False                 False                    False
# 43999               False                 False                    False
#
#        moon_phase_New Moon  moon_phase_Waning Crescent  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                        True
# 5                    False                       False
# ...                    ...                         ...
# 43995                False                       False
# 43996                False                       False
# 43997                False                       False
# 43998                False                        True
# 43999                False                       False
#
#        moon_phase_Waning Gibbous  moon_phase_Waxing Crescent  \
# 0                          False                        True
# 1                          False                       False
# 2                           True                       False
# 3                          False                       False
# 5                           True                       False
# ...                          ...                         ...
# 43995                      False                        True
# 43996                      False                       False
# 43997                       True                       False
# 43998                      False                       False
# 43999                      False                       False
#
#        moon_phase_Waxing Gibbous
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 5                          False
# ...                          ...
# 43995                      False
# 43996                       True
# 43997                      False
# 43998                      False
# 43999                       True
#
# [42826 rows x 54 columns]

# %%
# to join data with encoded data and drop unwanted columns
DATA=pd.concat([data1,new_data],axis=1)
DATA.drop(['region','wind_direction','moon_phase'],axis=1,inplace=True)
DATA
# Out:
#        region_Andhra Pradesh  region_Arunachal Pradesh  region_Assam  \
# 0                      False                     False         False
# 1                      False                     False         False
# 2                      False                     False         False
# 3                      False                     False         False
# 5                      False                     False         False
# ...                      ...                       ...           ...
# 43995                  False                     False         False
# 43996                   True                     False         False
# 43997                  False                     False         False
# 43998                  False                     False         False
# 43999                  False                     False         False
#
#        region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 0             False              False                False
# 1             False              False                False
# 2              True              False                False
# 3             False              False                False
# 5             False              False                False
# ...             ...                ...                  ...
# 43995         False              False                False
# 43996         False              False                False
# 43997         False              False                 True
# 43998         False              False                False
# 43999         False              False                False
#
#        region_Dadra and Nagar Haveli  region_Daman and Diu  region_Delhi  \
# 0                              False                 False         False
# 1                              False                 False         False
# 2                              False                 False         False
# 3                              False                 False         False
# 5                              False                 False         False
# ...                              ...                   ...           ...
# 43995                          False                 False         False
# 43996                          False                 False         False
# 43997                          False                 False         False
# 43998                          False                 False         False
# 43999                          False                 False         False
#
#        region_Goa  ...  air_quality_PM2.5  air_quality_PM10  \
# 0           False  ...               93.0             104.7
# 1           False  ...               45.2              74.3
# 2           False  ...              132.2             179.6
# 3           False  ...               22.4              28.8
# 5           False  ...               19.4              26.0
# ...           ...  ...                ...               ...
# 43995       False  ...               32.2              33.3
# 43996       False  ...               42.1              43.9
# 43997       False  ...              156.4             161.6
# 43998       False  ...               30.8              38.1
# 43999       False  ...               16.5              20.9
#
#        air_quality_us-epa-index  air_quality_gb-defra-index   sunrise  \
# 0                             4                          10  6.383333
# 1                             3                           5  7.233333
# 2                             4                          10  6.233333
# 3                             2                           2  6.433333
# 5                             2                           2  6.800000
# ...                         ...                         ...       ...
# 43995                         2                           3  5.816667
# 43996                         3                           5  6.500000
# 43997                         5                          10  6.350000
# 43998                         2                           3  5.866667
# 43999                         2                           2  5.016667
#
#          sunset   moonrise    moonset  moon_illumination  weather
# 0      5.683333  12.783333  10.833333                 37        1
# 1      6.266667   0.000000  11.383333                 59        1
# 2      5.733333   6.500000   6.733333                100        1
# 3      6.183333   1.166667  11.700000                 46        1
# 5      5.183333  11.483333  12.183333                 62        1
# ...         ...        ...        ...                ...      ...
# 43995  6.016667  10.366667   9.066667                 22        3
# 43996  5.616667   4.733333   5.250000                 98        3
# 43997  5.366667   6.100000   7.133333                 99        3
# 43998  6.433333   0.000000   2.350000                 39        3
# 43999  5.033333   3.866667   2.350000                 91        3
#
# [42826 rows x 90 columns]

# %%
sns.heatmap(DATA.corr())
# Out:
# <Axes: >

# %%
DATA.columns
# Out:
# Index(['region_Andhra Pradesh', 'region_Arunachal Pradesh', 'region_Assam',
#        'region_Bihar', 'region_Chandigarh', 'region_Chhattisgarh',
#        'region_Dadra and Nagar Haveli', 'region_Daman and Diu', 'region_Delhi',
#        'region_Goa', 'region_Gujarat', 'region_Haryana',
#        'region_Himachal Pradesh', 'region_Jammu and Kashmir',
#        'region_Jharkhand', 'region_Karnataka', 'region_Kerala',
#        'region_Lakshadweep', 'region_Madhya Pradesh', 'region_Maharashtra',
#        'region_Manipur', 'region_Mizoram', 'region_Nagaland', 'region_Orissa',
#        'region_Puducherry', 'region_Punjab', 'region_Rajasthan',
#        'region_Tamil Nadu', 'region_Tripura', 'region_Uttar Pradesh',
#        'region_Uttarakhand', 'region_West Bengal', 'wind_direction_ENE',
#        'wind_direction_ESE', 'wind_direction_N', 'wind_direction_NE',
#        'wind_direction_NNE', 'wind_direction_NNW', 'wind_direction_NW',
#        'wind_direction_S', 'wind_direction_SE', 'wind_direction_SSE',
#        'wind_direction_SSW', 'wind_direction_SW', 'wind_direction_W',
#        'wind_direction_WNW', 'wind_direction_WSW', 'moon_phase_Full Moon',
#        'moon_phase_Last Quarter', 'moon_phase_New Moon',
#        'moon_phase_Waning Crescent', 'moon_phase_Waning Gibbous',
#        'moon_phase_Waxing Crescent', 'moon_phase_Waxing Gibbous', 'latitude',
#        'longitude', 'last_updated_epoch', 'last_updated',
#        'temperature_celsius', 'temperature_fahrenheit', 'wind_mph', 'wind_kph',
#        'wind_degree', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in',
#        'humidity', 'cloud', 'feels_like_celsius', 'feels_like_fahrenheit',
#        'visibility_km', 'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'sunrise', 'sunset', 'moonrise',
#        'moonset', 'moon_illumination', 'weather'],
#       dtype='object')

# %% [markdown]
# SEPARATING X AS INPUT AND Y AS OUTPUT

# %%
x=DATA.drop(['weather'],axis=1)
x
# Out:
#        region_Andhra Pradesh  region_Arunachal Pradesh  region_Assam  \
# 0                      False                     False         False
# 1                      False                     False         False
# 2                      False                     False         False
# 3                      False                     False         False
# 5                      False                     False         False
# ...                      ...                       ...           ...
# 43995                  False                     False         False
# 43996                   True                     False         False
# 43997                  False                     False         False
# 43998                  False                     False         False
# 43999                  False                     False         False
#
#        region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 0             False              False                False
# 1             False              False                False
# 2              True              False                False
# 3             False              False                False
# 5             False              False                False
# ...             ...                ...                  ...
# 43995         False              False                False
# 43996         False              False                False
# 43997         False              False                 True
# 43998         False              False                False
# 43999         False              False                False
#
#        region_Dadra and Nagar Haveli  region_Daman and Diu  region_Delhi  \
# 0                              False                 False         False
# 1                              False                 False         False
# 2                              False                 False         False
# 3                              False                 False         False
# 5                              False                 False         False
# ...                              ...                   ...           ...
# 43995                          False                 False         False
# 43996                          False                 False         False
# 43997                          False                 False         False
# 43998                          False                 False         False
# 43999                          False                 False         False
#
#        region_Goa  ...  air_quality_Sulphur_dioxide  air_quality_PM2.5  \
# 0           False  ...                          5.0               93.0
# 1           False  ...                          1.4               45.2
# 2           False  ...                         10.0              132.2
# 3           False  ...                          1.6               22.4
# 5           False  ...                          0.9               19.4
# ...           ...  ...                          ...                ...
# 43995       False  ...                          0.5               32.2
# 43996       False  ...                          2.6               42.1
# 43997       False  ...                          3.3              156.4
# 43998       False  ...                          3.3               30.8
# 43999       False  ...                          1.0               16.5
#
#        air_quality_PM10  air_quality_us-epa-index  air_quality_gb-defra-index  \
# 0                 104.7                         4                          10
# 1                  74.3                         3                           5
# 2                 179.6                         4                          10
# 3                  28.8                         2                           2
# 5                  26.0                         2                           2
# ...                 ...                       ...                         ...
# 43995              33.3                         2                           3
# 43996              43.9                         3                           5
# 43997             161.6                         5                          10
# 43998              38.1                         2                           3
# 43999              20.9                         2                           2
#
#         sunrise    sunset   moonrise    moonset  moon_illumination
# 0      6.383333  5.683333  12.783333  10.833333                 37
# 1      7.233333  6.266667   0.000000  11.383333                 59
# 2      6.233333  5.733333   6.500000   6.733333                100
# 3      6.433333  6.183333   1.166667  11.700000                 46
# 5      6.800000  5.183333  11.483333  12.183333                 62
# ...         ...       ...        ...        ...                ...
# 43995  5.816667  6.016667  10.366667   9.066667                 22
# 43996  6.500000  5.616667   4.733333   5.250000                 98
# 43997  6.350000  5.366667   6.100000   7.133333                 99
# 43998  5.866667  6.433333   0.000000   2.350000                 39
# 43999  5.016667  5.033333   3.866667   2.350000                 91
#
# [42826 rows x 89 columns]

# %%
y=DATA['weather']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 5        1
#         ..
# 43995    3
# 43996    3
# 43997    3
# 43998    3
# 43999    3
# Name: weather, Length: 42826, dtype: int64

# %% [markdown]
# SPLITTING DATA INTO TRAIN SET AND TEST SET

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#        region_Andhra Pradesh  region_Arunachal Pradesh  region_Assam  \
# 32289                  False                     False         False
# 24546                  False                     False         False
# 8941                   False                     False         False
# 12605                  False                     False         False
# 35636                  False                     False         False
# ...                      ...                       ...           ...
# 6525                   False                     False         False
# 11737                  False                     False         False
# 39220                   True                     False         False
# 899                    False                     False         False
# 16321                  False                     False         False
#
#        region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 32289         False              False                False
# 24546         False              False                False
# 8941          False              False                False
# 12605         False              False                False
# 35636         False              False                False
# ...             ...                ...                  ...
# 6525          False              False                False
# 11737         False              False                False
# 39220         False              False                False
# 899           False              False                False
# 16321         False              False                False
#
#        region_Dadra and Nagar Haveli  region_Daman and Diu  region_Delhi  \
# 32289                          False                 False         False
# 24546                          False                 False         False
# 8941                           False                 False         False
# 12605                          False                 False         False
# 35636                          False                 False         False
# ...                              ...                   ...           ...
# 6525                           False                 False         False
# 11737                          False                 False         False
# 39220                          False                 False         False
# 899                            False                 False         False
# 16321                          False                 False         False
#
#        region_Goa  ...  air_quality_Sulphur_dioxide  air_quality_PM2.5  \
# 32289       False  ...                          5.1               11.1
# 24546       False  ...                          6.6               87.5
# 8941        False  ...                          2.0               22.5
# 12605       False  ...                         10.0               26.9
# 35636       False  ...                          0.2                6.2
# ...           ...  ...                          ...                ...
# 6525        False  ...                         18.6               74.2
# 11737       False  ...                          5.5               63.6
# 39220       False  ...                          0.5               33.5
# 899         False  ...                         11.1              111.1
# 16321       False  ...                          3.3              134.9
#
#        air_quality_PM10  air_quality_us-epa-index  air_quality_gb-defra-index  \
# 32289              12.5                         1                           1
# 24546             107.9                         4                          10
# 8941               38.2                         2                           2
# 12605              34.0                         2                           3
# 35636               6.9                         1                           1
# ...                 ...                       ...                         ...
# 6525               82.2                         4                          10
# 11737              66.8                         3                           8
# 39220              37.4                         2                           3
# 899               134.4                         4                          10
# 16321             142.7                         4                          10
#
#         sunrise    sunset   moonrise    moonset  moon_illumination
# 32289  6.366667  5.833333   4.183333   4.200000                 93
# 24546  6.516667  5.883333  10.400000  10.383333                 78
# 8941   5.883333  6.500000   8.250000   8.033333                 94
# 12605  6.783333  6.416667   7.850000   7.933333                 98
# 35636  5.916667  6.300000   5.033333   6.150000                  1
# ...         ...       ...        ...        ...                ...
# 6525   6.133333  6.666667  12.666667   3.483333                 30
# 11737  6.166667  5.133333  12.883333   1.183333                 34
# 39220  6.466667  5.666667   4.033333   4.233333                 93
# 899    6.650000  5.766667   3.283333   1.750000                 20
# 16321  5.750000  5.283333   2.933333   1.950000                 81
#
# [29978 rows x 89 columns]

# %%
x_test
# Out:
#        region_Andhra Pradesh  region_Arunachal Pradesh  region_Assam  \
# 19388                  False                     False         False
# 15555                  False                     False         False
# 34918                  False                     False         False
# 18799                  False                     False         False
# 20477                  False                     False         False
# ...                      ...                       ...           ...
# 5763                   False                     False         False
# 14818                  False                     False         False
# 1883                   False                     False         False
# 25161                  False                     False         False
# 41454                  False                     False         False
#
#        region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 19388         False              False                False
# 15555         False              False                False
# 34918         False              False                False
# 18799         False              False                False
# 20477          True              False                False
# ...             ...                ...                  ...
# 5763          False              False                 True
# 14818         False              False                False
# 1883          False              False                False
# 25161         False              False                False
# 41454         False              False                False
#
#        region_Dadra and Nagar Haveli  region_Daman and Diu  region_Delhi  \
# 19388                          False                 False         False
# 15555                          False                 False         False
# 34918                          False                 False         False
# 18799                          False                 False         False
# 20477                          False                 False         False
# ...                              ...                   ...           ...
# 5763                           False                 False         False
# 14818                          False                 False         False
# 1883                           False                 False         False
# 25161                          False                 False         False
# 41454                          False                 False         False
#
#        region_Goa  ...  air_quality_Sulphur_dioxide  air_quality_PM2.5  \
# 19388       False  ...                          2.5              217.4
# 15555       False  ...                          0.4                1.4
# 34918       False  ...                         10.0              167.4
# 18799       False  ...                          6.0              250.4
# 20477       False  ...                          5.3              162.3
# ...           ...  ...                          ...                ...
# 5763        False  ...                         53.4              186.3
# 14818       False  ...                          0.5                3.4
# 1883        False  ...                          6.5               74.8
# 25161       False  ...                          7.3               15.0
# 41454       False  ...                          4.3               93.6
#
#        air_quality_PM10  air_quality_us-epa-index  air_quality_gb-defra-index  \
# 19388             237.5                         5                          10
# 15555               1.9                         1                           1
# 34918             194.3                         5                          10
# 18799             293.8                         6                          10
# 20477             212.1                         5                          10
# ...                 ...                       ...                         ...
# 5763              203.4                         5                          10
# 14818               4.0                         1                           1
# 1883               79.8                         4                          10
# 25161              27.0                         1                           2
# 41454              96.5                         4                          10
#
#         sunrise    sunset   moonrise    moonset  moon_illumination
# 19388  6.383333  5.350000   0.000000  11.683333                 51
# 15555  5.616667  6.083333   0.000000   1.766667                 39
# 34918  7.150000  5.516667   7.033333   9.083333                 97
# 18799  6.800000  5.433333   2.733333   2.366667                 78
# 20477  6.050000  5.050000   3.083333   3.216667                 11
# ...         ...       ...        ...        ...                ...
# 5763   6.650000  5.483333   0.000000  11.866667                 51
# 14818  5.083333  5.183333   1.550000   0.000000                 63
# 1883   7.316667  6.200000   6.150000   4.950000                  3
# 25161  6.733333  6.566667   5.000000   5.233333                 94
# 41454  6.783333  5.500000  10.866667  11.683333                 71
#
# [12848 rows x 89 columns]

# %%
y_train
# Out:
# 32289    2
# 24546    2
# 8941     1
# 12605    0
# 35636    3
#         ..
# 6525     1
# 11737    0
# 39220    3
# 899      1
# 16321    0
# Name: weather, Length: 29978, dtype: int64

# %%
y_test
# Out:
# 19388    0
# 15555    0
# 34918    3
# 18799    0
# 20477    0
#         ..
# 5763     1
# 14818    0
# 1883     1
# 25161    2
# 41454    3
# Name: weather, Length: 12848, dtype: int64

# %% [markdown]
# NORMALIZATION

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# MODEL CREATION

# %% [markdown]
# K Nearest Neighbors Model and its Performance Evaluation

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report

# %%
# # Hyper Parameter Tuning
# from sklearn.model_selection import GridSearchCV
# clf=KNeighborsClassifier()
# pmtr={'n_neighbors':[3,5,7,9,11],'weights':['uniform','distance']}
# gd=GridSearchCV(clf,pmtr,cv=10,scoring='accuracy')  # CV = CrossValidation
# gd.fit(x_train,y_train)

# %%
# print(gd.best_params_)

# %%
k_model=KNeighborsClassifier(n_neighbors=11,weights='distance')
k_model.fit(x_train,y_train)
y_pred1=k_model.predict(x_test)
mat=confusion_matrix(y_test,y_pred1)
print(mat)
dis=ConfusionMatrixDisplay(mat,display_labels=['MISTY','CLOUDY','RAINY','CLEAR'])
dis.plot()
print(classification_report(y_test,y_pred1))
# Out:
# [[2955   47   86  108]
#  [  42 2617  468  103]
#  [ 143  503 2012  548]
#  [ 140   96  498 2482]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      3196
#            1       0.80      0.81      0.81      3230
#            2       0.66      0.63      0.64      3206
#            3       0.77      0.77      0.77      3216
#
#     accuracy                           0.78     12848
#    macro avg       0.78      0.78      0.78     12848
# weighted avg       0.78      0.78      0.78     12848

# %% [markdown]
# Support Vector Machine Model and its Performance Evaluation

# %%
from sklearn.svm import SVC
s_model=SVC()
s_model.fit(x_train,y_train)
y_pred3=s_model.predict(x_test)
mat=confusion_matrix(y_test,y_pred3)
print(mat)
dis=ConfusionMatrixDisplay(mat,display_labels=['MISTY','CLOUDY','RAINY','CLEAR'])
dis.plot()
print(classification_report(y_test,y_pred3))
# Out:
# [[3133   10   29   24]
#  [  19 3088  123    0]
#  [ 147    4 2649  406]
#  [ 226    0  242 2748]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3196
#            1       1.00      0.96      0.98      3230
#            2       0.87      0.83      0.85      3206
#            3       0.86      0.85      0.86      3216
#
#     accuracy                           0.90     12848
#    macro avg       0.90      0.90      0.90     12848
# weighted avg       0.91      0.90      0.90     12848

# %% [markdown]
# Decision Tree Model and its Performance Evaluation

# %%
from sklearn.tree import DecisionTreeClassifier
t_model=DecisionTreeClassifier()
t_model.fit(x_train,y_train)
y_pred4=t_model.predict(x_test)
mat=confusion_matrix(y_test,y_pred4)
print(mat)
dis=ConfusionMatrixDisplay(mat,display_labels=['MISTY','CLOUDY','RAINY','CLEAR'])
dis.plot()
print(classification_report(y_test,y_pred4))
# since it has large no. of features, creation of tree is difficult
# Out:
# [[3091    4   28   73]
#  [   1 3218   11    0]
#  [  25   13 3166    2]
#  [  59    0    0 3157]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3196
#            1       0.99      1.00      1.00      3230
#            2       0.99      0.99      0.99      3206
#            3       0.98      0.98      0.98      3216
#
#     accuracy                           0.98     12848
#    macro avg       0.98      0.98      0.98     12848
# weighted avg       0.98      0.98      0.98     12848

# %% [markdown]
# Random Forest Model and its Performance Evaluation

# %%
from sklearn.ensemble import RandomForestClassifier
r_model=RandomForestClassifier()
r_model.fit(x_train,y_train)
y_pred5=t_model.predict(x_test)
mat=confusion_matrix(y_test,y_pred5)
print(mat)
dis=ConfusionMatrixDisplay(mat,display_labels=['MISTY','CLOUDY','RAINY','CLEAR'])
dis.plot()
print(classification_report(y_test,y_pred5))
# Out:
# [[3091    4   28   73]
#  [   1 3218   11    0]
#  [  25   13 3166    2]
#  [  59    0    0 3157]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3196
#            1       0.99      1.00      1.00      3230
#            2       0.99      0.99      0.99      3206
#            3       0.98      0.98      0.98      3216
#
#     accuracy                           0.98     12848
#    macro avg       0.98      0.98      0.98     12848
# weighted avg       0.98      0.98      0.98     12848

# %%
x_test[0:5]
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.74817518e-01, 6.20573984e-01,
#         6.82011605e-01, 0.00000000e+00, 3.32236842e-01, 3.32723949e-01,
#         0.00000000e+00, 0.00000000e+00, 2.50696379e-02, 7.14285714e-01,
#         7.10843373e-01, 0.00000000e+00, 0.00000000e+00, 9.30232558e-01,
#         0.00000000e+00, 2.75210084e-01, 2.75379230e-01, 2.00000000e-01,
#         1.66666667e-01, 0.00000000e+00, 1.01960784e-01, 1.00973236e-01,
#         5.95288052e-02, 2.71294929e-01, 2.89188301e-02, 5.60161326e-03,
#         1.63242267e-01, 1.54056340e-01, 8.00000000e-01, 1.00000000e+00,
#         5.73099415e-01, 3.81215470e-01, 0.00000000e+00, 8.99871630e-01,
#         5.10000000e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 6.17883212e-01, 8.44576966e-01,
#         5.69770655e-02, 7.27272727e-01, 5.98684211e-01, 5.99634369e-01,
#         2.06611570e-02, 1.79948586e-02, 4.40111421e-01, 3.57142857e-01,
#         3.49397590e-01, 0.00000000e+00, 0.00000000e+00, 9.76744186e-01,
#         1.00000000e+00, 5.06302521e-01, 5.06417736e-01, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 9.21568627e-02, 9.24574209e-02,
#         8.75247287e-03, 4.08665682e-02, 4.92934604e-03, 8.96258122e-04,
#         6.77353804e-04, 7.80690911e-04, 0.00000000e+00, 0.00000000e+00,
#         3.04093567e-01, 6.24309392e-01, 0.00000000e+00, 1.36071887e-01,
#         3.90000000e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 8.50729927e-01, 2.06857995e-01,
#         4.91240674e-01, 9.09090909e-01, 4.40789474e-01, 4.40585009e-01,
#         7.43801653e-02, 7.45501285e-02, 1.86629526e-01, 6.42857143e-01,
#         6.26506024e-01, 5.25114155e-03, 5.81395349e-03, 3.83720930e-01,
#         7.50000000e-01, 3.44537815e-01, 3.44224037e-01, 5.00000000e-01,
#         5.00000000e-01, 0.00000000e+00, 1.54901961e-01, 1.54501217e-01,
#         8.05407350e-02, 2.39290990e-01, 7.88695366e-02, 2.24064531e-02,
#         1.25611500e-01, 1.25951467e-01, 8.00000000e-01, 1.00000000e+00,
#         8.42105263e-01, 4.36464088e-01, 5.41720154e-01, 6.99614891e-01,
#         9.70000000e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 7.65693431e-01, 3.11591502e-01,
#         4.59463940e-01, 9.09090909e-01, 2.99342105e-01, 2.99817185e-01,
#         0.00000000e+00, 0.00000000e+00, 2.50696379e-02, 6.42857143e-01,
#         6.38554217e-01, 0.00000000e+00, 0.00000000e+00, 7.32558140e-01,
#         0.00000000e+00, 2.64705882e-01, 2.64877480e-01, 1.30000000e-01,
#         0.00000000e+00, 0.00000000e+00, 1.19607843e-01, 1.19221411e-01,
#         1.13557341e-01, 1.53126539e-01, 1.22905028e-01, 1.34438718e-02,
#         1.88078573e-01, 1.90683755e-01, 1.00000000e+00, 1.00000000e+00,
#         7.19298246e-01, 4.08839779e-01, 2.10526316e-01, 1.82284981e-01,
#         7.80000000e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 6.72627737e-01, 6.01938129e-01,
#         3.90549876e-01, 9.09090909e-01, 5.62500000e-01, 5.63071298e-01,
#         0.00000000e+00, 0.00000000e+00, 2.50696379e-02, 6.42857143e-01,
#         6.38554217e-01, 0.00000000e+00, 0.00000000e+00, 9.30232558e-01,
#         0.00000000e+00, 4.60084034e-01, 4.59743291e-01, 1.30000000e-01,
#         0.00000000e+00, 0.00000000e+00, 2.74509804e-02, 2.79805353e-02,
#         1.05554223e-01, 3.74199902e-02, 1.04830759e-01, 1.18754201e-02,
#         1.21773162e-01, 1.37531716e-01, 8.00000000e-01, 1.00000000e+00,
#         4.56140351e-01, 2.81767956e-01, 2.37483954e-01, 2.47753530e-01,
#         1.10000000e-01]])

# %%
value = r_model.predict ([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
        0.00000000e+00, 0.00000000e+00, 4.74817518e-01, 6.20573984e-01,
        6.82011605e-01, 0.00000000e+00, 3.32236842e-01, 3.32723949e-01,
        0.00000000e+00, 0.00000000e+00, 2.50696379e-02, 7.14285714e-01,
        7.10843373e-01, 0.00000000e+00, 0.00000000e+00, 9.30232558e-01,
        0.00000000e+00, 2.75210084e-01, 2.75379230e-01, 2.00000000e-01,
        1.66666667e-01, 0.00000000e+00, 1.01960784e-01, 1.00973236e-01,
        5.95288052e-02, 2.71294929e-01, 2.89188301e-02, 5.60161326e-03,
        1.63242267e-01, 1.54056340e-01, 8.00000000e-01, 1.00000000e+00,
        5.73099415e-01, 3.81215470e-01, 0.00000000e+00, 8.99871630e-01,
        5.10000000e-01]])
print(value)
# Out:
# [0]

# %%
y_test[0:5]
# Out:
# 19388    0
# 15555    0
# 34918    3
# 18799    0
# 20477    0
# Name: weather, dtype: int64

# %%
if value[0] == 0:
  print('MISTY')
elif value[0] == 1:
  print('CLEAR')
elif value[0] == 2:
  print('CLOUDY')
elif value[0] == 3:
  print('RAINY')
else:
  pass
# Out:
# MISTY

# %%
# pickle used for saving and loading machine learning models, among other purposes.
import pickle
pickle.dump(r_model,open('/content/randomforest_model.pkl','wb'))
# the trained Random Forest model r_model will be saved as a binary file named
# 'randomforest_model.pkl' in the specified location ('/content' directory in this case).
# later can load this model from the saved file using pickle.load() to make predictions on new data or to continue training.

# %%
# when you run ! pip install streamlit -q in a Jupyter Notebook or IPython environment,
# it will install the streamlit package quietly, without displaying detailed installation messages
! pip install streamlit -q

# %%
DATA.columns
# Out:
# Index(['region_Andhra Pradesh', 'region_Arunachal Pradesh', 'region_Assam',
#        'region_Bihar', 'region_Chandigarh', 'region_Chhattisgarh',
#        'region_Dadra and Nagar Haveli', 'region_Daman and Diu', 'region_Delhi',
#        'region_Goa', 'region_Gujarat', 'region_Haryana',
#        'region_Himachal Pradesh', 'region_Jammu and Kashmir',
#        'region_Jharkhand', 'region_Karnataka', 'region_Kerala',
#        'region_Lakshadweep', 'region_Madhya Pradesh', 'region_Maharashtra',
#        'region_Manipur', 'region_Mizoram', 'region_Nagaland', 'region_Orissa',
#        'region_Puducherry', 'region_Punjab', 'region_Rajasthan',
#        'region_Tamil Nadu', 'region_Tripura', 'region_Uttar Pradesh',
#        'region_Uttarakhand', 'region_West Bengal', 'wind_direction_ENE',
#        'wind_direction_ESE', 'wind_direction_N', 'wind_direction_NE',
#        'wind_direction_NNE', 'wind_direction_NNW', 'wind_direction_NW',
#        'wind_direction_S', 'wind_direction_SE', 'wind_direction_SSE',
#        'wind_direction_SSW', 'wind_direction_SW', 'wind_direction_W',
#        'wind_direction_WNW', 'wind_direction_WSW', 'moon_phase_Full Moon',
#        'moon_phase_Last Quarter', 'moon_phase_New Moon',
#        'moon_phase_Waning Crescent', 'moon_phase_Waning Gibbous',
#        'moon_phase_Waxing Crescent', 'moon_phase_Waxing Gibbous', 'latitude',
#        'longitude', 'last_updated_epoch', 'last_updated',
#        'temperature_celsius', 'temperature_fahrenheit', 'wind_mph', 'wind_kph',
#        'wind_degree', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in',
#        'humidity', 'cloud', 'feels_like_celsius', 'feels_like_fahrenheit',
#        'visibility_km', 'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'sunrise', 'sunset', 'moonrise',
#        'moonset', 'moon_illumination', 'weather'],
#       dtype='object')

# %%
non_boolean_features = [col for col in DATA.columns if DATA[col].dtype != bool]
for i in non_boolean_features:
  print(i,",","max:",max(new_data[i]),"min:",min(new_data[i]))
# Out:
# latitude , max: 34.57 min: 7.17
# longitude , max: 95.8 min: 68.97
# last_updated_epoch , max: 1709571600 min: 1693286100
# last_updated , max: 12 min: 1
# temperature_celsius , max: 36.3 min: 5.9
# temperature_fahrenheit , max: 97.3 min: 42.6
# wind_mph , max: 26.4 min: 2.2
# wind_kph , max: 42.5 min: 3.6
# wind_degree , max: 360 min: 1
# pressure_mb , max: 1025.0 min: 997.0
# pressure_in , max: 30.27 min: 29.44
# precip_mm , max: 43.8 min: 0.0
# precip_in , max: 1.72 min: 0.0
# humidity , max: 100 min: 14
# cloud , max: 100 min: 0
# feels_like_celsius , max: 50.5 min: 2.9
# feels_like_fahrenheit , max: 122.9 min: 37.2
# visibility_km , max: 10.0 min: 0.0
# visibility_miles , max: 6.0 min: 0.0
# uv_index , max: 9.0 min: 1.0
# gust_mph , max: 51.0 min: 0.0
# gust_kph , max: 82.2 min: 0.0
# air_quality_Carbon_Monoxide , max: 13458.3 min: 113.5
# air_quality_Ozone , max: 234.6 min: 0.0
# air_quality_Nitrogen_dioxide , max: 304.3 min: 0.0
# air_quality_Sulphur_dioxide , max: 541.7 min: 0.0
# air_quality_PM2.5 , max: 1329.2 min: 0.5
# air_quality_PM10 , max: 1537.8 min: 0.7
# air_quality_us-epa-index , max: 6 min: 1
# air_quality_gb-defra-index , max: 10 min: 1
# sunrise , max: 7.616666666666667 min: 4.733333333333333
# sunset , max: 7.216666666666667 min: 4.2
# moonrise , max: 12.983333333333333 min: 0.0
# moonset , max: 12.983333333333333 min: 0.0
# moon_illumination , max: 100 min: 0
# weather , max: 3 min: 0

# %%
# boolean_features = [col for col in DATA.columns if DATA[col].dtype == bool]
# boolean_features

# %%
! wget -q -O - ipv4.icanhazip.com
# without opening a web browser, this command is useful for quickly finding out public IP address
# Out:
# 34.82.51.128

# %%
! streamlit run app.py & npx localtunnel --port 8501
# can easily run and share our local Streamlit app over the internet for demonstration, feedback, or testing purposes
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.82.51.128:8501
#
# npx: installed 22 in 2.931s
# your url is: https://seven-breads-sort.loca.lt
#   Stopping...
# ^C
